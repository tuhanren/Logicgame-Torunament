# %% [markdown]
# <a href="https://colab.research.google.com/github/tuhanren/Logicgame-Torunament/blob/main/logicagme_tournament_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Section 1: Core Game Functionality**
# This section focuses on implementing the core logic of the game, including:
#
# 1. **Number Generation and Validation**:
#    - `generate_secret_number`: Responsible for generating a valid secret number.
#    - `is_valid_guess`: Validates if the player's guess follows the game rules (e.g., no duplicate digits, within the valid range).
#    - `evaluate_guess`: Compares the player's guess against the secret number and evaluates the result.
#
# 2. **Core Mechanics**:
#    - These functions form the foundational logic for running the game, managing rules, and handling player input and scoring.

# %%
import random
import time
from dataclasses import dataclass, field
from typing import List
from itertools import permutations


# Define player data class
@dataclass
class Player:
    name: str
    total_score: int = 0  # Total score
    total_attempts: int = 0  # Total attempts (only player attempts)
    total_time_taken: float = 0.0  # Total time taken
    round_score: int = 0  # Score for the current round
    round_attempts: int = 0  # Attempts for the current round (including player's attempts)
    round_time_taken: float = 0.0  # Time taken for the current round (in seconds)


@dataclass
class Tournament:
    players: List[Player] = field(default_factory=list)

    def register_player(self, name: str):
        """Register a new player"""
        player = Player(name)
        self.players.append(player)
        print(f"Player {name} has been registered.")

    def play_game_player_guesses(self, player: Player):
        """Game: Player guesses the computer's secret number"""
        secret_number = generate_secret_number()
        print(f"{player.name}, the game begins! The computer has generated a secret three-digit number: {secret_number}")
        attempts = 0
        start_time = time.time()
        while True:
            guess = input("Enter your guess (e.g., 123): ")

            if not is_valid_guess(guess):
                print("Invalid input! The number must be a three-digit number without zeros or duplicate digits. Please try again.")
                continue

            attempts += 1
            feedback = evaluate_guess(guess, secret_number)
            print(f"Feedback: {feedback}")
            if feedback == "+++":  # Guessed correctly
                end_time = time.time()
                time_taken = end_time - start_time
                player.round_time_taken = time_taken
                player.round_attempts += attempts
                player.total_attempts += attempts  # Update the player's total attempts
                score = self.calculate_score(attempts)
                player.round_score = score
                player.total_score += score
                player.total_time_taken += time_taken

                print(f"Congratulations! You guessed the secret number {secret_number} in {attempts} attempts!")
                print(f"You took {time_taken:.2f} seconds to complete the game.")
                break

    def play_game_computer_guesses(self, player: Player):
        """Optimized computer guessing algorithm"""
        groups = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
        answer_list = []
        attempts = 0  # Separate counter for computer's guesses

        while True:
            secret_number = input(f"{player.name}, please provide a three-digit secret number for the computer (no zeros or duplicate digits): ")
            if is_valid_guess(secret_number):
                break
            print("Invalid input! Please enter a three-digit number without zeros or duplicate digits.")

        # Phase 1: Group processing
        for group in groups:
            guess = ''.join(map(str, group))
            feedback = evaluate_guess(guess, secret_number)
            print(f"Computer's guess: {guess}, Feedback: {feedback}")
            attempts += 1

            if feedback == "":  # No match
                continue
            if feedback == "+++":  # Fully matched
                print(f"The computer guessed the secret number: {guess}")
                return attempts  # Return the number of computer's guesses

            for num in group:
                temp_guess = str(num) * 3
                temp_feedback = evaluate_guess(temp_guess, secret_number)
                print(f"Computer's guess: {temp_guess}, Feedback: {temp_feedback}")
                attempts += 1
                if temp_feedback != "":
                    answer_list.append(num)

                if len(answer_list) == 3:  # After finding three digits, adjust their positions
                    adjusted_list, attempts = self.adjust_positions(answer_list, secret_number, attempts)
                    final_guess = ''.join(map(str, adjusted_list))
                    print(f"The computer guessed the secret number: {final_guess}")
                    return attempts  # Return the number of computer's guesses

    def adjust_positions(self, answer_list: List[int], target: str, attempts: int) -> List[int]:
        """Adjust the positions in answer_list until feedback is +++"""
        for perm in permutations(answer_list):
            guess = ''.join(map(str, perm))
            feedback = evaluate_guess(guess, target)
            print(f"Computer tries permutation: {guess}, Feedback: {feedback}")
            attempts += 1
            if feedback == "+++":
                return list(perm), attempts
        return answer_list, attempts

    def calculate_score(self, attempts: int) -> int:
        """Calculate the score based on the number of attempts"""
        if attempts <= 3:
            return 3
        elif attempts <= 6:
            return 2
        elif attempts <= 9:
            return 1
        else:
            return 0

    def display_round_results(self):
        """Display results for the current round and the cumulative leaderboard"""
        # 1. Round leaderboard
        print("\nRound Leaderboard:")
        print(f"{'Rank':<5}{'Player':<8}{'Score':<8}{'Attempts':<10}{'Time (s)':<10}")
        round_leaderboard = sorted(
            self.players,
            key=lambda x: (-x.round_score, x.round_attempts, x.round_time_taken)
        )
        for rank, player in enumerate(round_leaderboard, 1):
            print(
                f"{rank:<6}{player.name:<10}{player.round_score:<10}{player.round_attempts:<10}{player.round_time_taken:<10.2f}"
            )

        # 2. Cumulative leaderboard
        print("\nCumulative Leaderboard:")
        print(f"{'Rank':<5}{'Player':<8}{'Score':<8}{'Attempts':<16}{'Time (s)':<15}")
        total_leaderboard = sorted(
            self.players,
            key=lambda x: (-x.total_score, x.total_attempts, x.total_time_taken)
        )
        for rank, player in enumerate(total_leaderboard, 1):
            print(
                f"{rank:<6}{player.name:<10}{player.total_score:<10}{player.total_attempts:<15}{player.total_time_taken:<15.2f}"
            )

    def play_tournament_round(self):
        """Each player plays one round, alternating between guessing and providing a number"""
        for player in self.players:
            print(f"\n{player.name}'s turn to guess the computer's number:")
            self.play_game_player_guesses(player)  # Player guesses the computer's number

            print(f"\nNow it's the computer's turn to guess {player.name}'s number:")
            computer_attempts = self.play_game_computer_guesses(player)  # Computer guesses the player's number
            print(f"The computer took {computer_attempts} attempts.")

            # Update the player's score, but do not include computer's guesses in player's data
            player.round_score += self.calculate_score(computer_attempts)
            player.total_score += self.calculate_score(computer_attempts)



def generate_secret_number() -> str:
    """Generate a three-digit number without duplicates or zeros"""
    digits = random.sample(range(1, 10), 3)
    return ''.join(map(str, digits))


def is_valid_guess(guess: str) -> bool:
    """Check if the guess is a valid three-digit number (no zeros or duplicates)"""
    if len(guess) != 3 or not guess.isdigit():
        return False
    if '0' in guess:
        return False
    if len(set(guess)) != len(guess):
        return False
    return True


def evaluate_guess(guess: str, secret_number: str) -> str:
    """Compare the player's guess to the secret number and provide feedback"""
    feedback = []
    secret_matched = [False] * 3
    guess_matched = [False] * 3

    for i in range(3):
        if guess[i] == secret_number[i]:
            feedback.append('+')
            secret_matched[i] = True
            guess_matched[i] = True

    for i in range(3):
        if not guess_matched[i]:
            for j in range(3):
                if not secret_matched[j] and guess[i] == secret_number[j]:
                    feedback.append('-')
                    secret_matched[j] = True
                    break

    return ''.join(feedback)


def main():
    print("Welcome to the Logic Game Tournament System!")
    tournament = Tournament()

    num_players = int(input("Enter the number of players: "))
    for i in range(num_players):
        name = input(f"Enter the name of Player {i + 1}: ")
        tournament.register_player(name)

    num_rounds = int(input("Enter the number of rounds: "))
    for _ in range(num_rounds):
        tournament.play_tournament_round()
        tournament.display_round_results()  # Display rankings and cumulative scores for this round


if __name__ == "__main__":
    main()
# Out:
# Welcome to the Logic Game Tournament System!
# Enter the number of players: 1
# Enter the name of Player 1: Andy
# Player Andy has been registered.
# Enter the number of rounds: 1
#
# Andy's turn to guess the computer's number:
# Andy, the game begins! The computer has generated a secret three-digit number: 382
# Enter your guess (e.g., 123): 283
# Feedback: +--
# Enter your guess (e.g., 123): 382
# Feedback: +++
# Congratulations! You guessed the secret number 382 in 2 attempts!
# You took 5.10 seconds to complete the game.
#
# Now it's the computer's turn to guess Andy's number:
# Andy, please provide a three-digit secret number for the computer (no zeros or duplicate digits): 259
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 259, Feedback: +++
# The computer guessed the secret number: 259
# The computer took 13 attempts.
#
# Round Leaderboard:
# Rank Player  Score   Attempts  Time (s)
# 1     Andy      3         2         5.10
#
# Cumulative Leaderboard:
# Rank Player  Score   Attempts        Time (s)
# 1     Andy      3         2              5.10

# %% [markdown]
# ### **Section 2: Performance Analysis and Simulation**
# This section focuses on analyzing and simulating the performance of the game logic:
#
# 1. **Performance Analysis**:
#    - `find_worst_case`: Evaluates the worst-case performance by iterating through all possible valid secret numbers (likely 504 unique numbers, assuming three digits with no repeated digits).
#    - Analyzes the efficiency and robustness of the guessing algorithm under edge cases.
#
# 2. **Testing and Benchmarking**:
#    - Uses tools like `unittest.mock.patch` to simulate player inputs for controlled testing.
#    - Incorporates timing functionality (via the `time` library) to measure performance.

# %%
import time
from unittest.mock import patch
# from game_tournament_en import Tournament, Player, is_valid_guess

def find_worst_case():
    # Setup
    tournament = Tournament()
    player = Player(name="TestPlayer")
    tournament.register_player(player.name)

    worst_case = None
    max_attempts = 0
    max_time = 0

    # Iterate over all 504 possible valid secret numbers
    for secret_number in range(123, 988):  # From 123 to 987 inclusive
        secret_number_str = str(secret_number)

        # Ensure the number is valid (unique digits and within valid range)
        if not is_valid_guess(secret_number_str):
            continue

        # Mock input to provide the secret number
        with patch("builtins.input", return_value=secret_number_str):
            # Measure performance
            start_time = time.time()
            attempts = tournament.play_game_computer_guesses(player)
            end_time = time.time()

        time_taken = end_time - start_time

        # Update worst-case scenario
        if attempts > max_attempts or (attempts == max_attempts and time_taken > max_time):
            max_attempts = attempts
            max_time = time_taken
            worst_case = secret_number_str

        print(f"Tested Secret: {secret_number_str}, Attempts: {attempts}, Time: {time_taken:.5f}s")

    # Print the worst case
    print("\nWorst Case Found!")
    print(f"Secret Number: {worst_case}")
    print(f"Max Attempts: {max_attempts}")
    print(f"Max Time Taken: {max_time:.5f}s")

if __name__ == "__main__":
    find_worst_case()
# Out:
# Streaming output truncated to the last 5000 lines.
# Computer tries permutation: 412, Feedback: +--
# Computer tries permutation: 421, Feedback: +++
# The computer guessed the secret number: 421
# Tested Secret: 421, Attempts: 12, Time: 0.00101s
# Computer's guess: 123, Feedback: ++
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer tries permutation: 234, Feedback: ---
# Computer tries permutation: 243, Feedback: +--
# Computer tries permutation: 324, Feedback: +--
# Computer tries permutation: 342, Feedback: ---
# Computer tries permutation: 423, Feedback: +++
# The computer guessed the secret number: 423
# Tested Secret: 423, Attempts: 11, Time: 0.00029s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 245, Feedback: +--
# Computer tries permutation: 254, Feedback: ---
# Computer tries permutation: 425, Feedback: +++
# The computer guessed the secret number: 425
# Tested Secret: 425, Attempts: 10, Time: 0.00029s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 246, Feedback: +--
# Computer tries permutation: 264, Feedback: ---
# Computer tries permutation: 426, Feedback: +++
# The computer guessed the secret number: 426
# Tested Secret: 426, Attempts: 11, Time: 0.00030s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 247, Feedback: +--
# Computer tries permutation: 274, Feedback: ---
# Computer tries permutation: 427, Feedback: +++
# The computer guessed the secret number: 427
# Tested Secret: 427, Attempts: 13, Time: 0.00033s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 248, Feedback: +--
# Computer tries permutation: 284, Feedback: ---
# Computer tries permutation: 428, Feedback: +++
# The computer guessed the secret number: 428
# Tested Secret: 428, Attempts: 14, Time: 0.00036s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 249, Feedback: +--
# Computer tries permutation: 294, Feedback: ---
# Computer tries permutation: 429, Feedback: +++
# The computer guessed the secret number: 429
# Tested Secret: 429, Attempts: 15, Time: 0.00049s
# Computer's guess: 123, Feedback: --
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer tries permutation: 134, Feedback: +--
# Computer tries permutation: 143, Feedback: ---
# Computer tries permutation: 314, Feedback: ---
# Computer tries permutation: 341, Feedback: +--
# Computer tries permutation: 413, Feedback: +--
# Computer tries permutation: 431, Feedback: +++
# The computer guessed the secret number: 431
# Tested Secret: 431, Attempts: 12, Time: 0.00032s
# Computer's guess: 123, Feedback: --
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer tries permutation: 234, Feedback: +--
# Computer tries permutation: 243, Feedback: ---
# Computer tries permutation: 324, Feedback: ---
# Computer tries permutation: 342, Feedback: +--
# Computer tries permutation: 423, Feedback: +--
# Computer tries permutation: 432, Feedback: +++
# The computer guessed the secret number: 432
# Tested Secret: 432, Attempts: 12, Time: 0.00031s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 345, Feedback: +--
# Computer tries permutation: 354, Feedback: ---
# Computer tries permutation: 435, Feedback: +++
# The computer guessed the secret number: 435
# Tested Secret: 435, Attempts: 10, Time: 0.00042s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 346, Feedback: +--
# Computer tries permutation: 364, Feedback: ---
# Computer tries permutation: 436, Feedback: +++
# The computer guessed the secret number: 436
# Tested Secret: 436, Attempts: 11, Time: 0.00029s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 347, Feedback: +--
# Computer tries permutation: 374, Feedback: ---
# Computer tries permutation: 437, Feedback: +++
# The computer guessed the secret number: 437
# Tested Secret: 437, Attempts: 13, Time: 0.00035s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 348, Feedback: +--
# Computer tries permutation: 384, Feedback: ---
# Computer tries permutation: 438, Feedback: +++
# The computer guessed the secret number: 438
# Tested Secret: 438, Attempts: 14, Time: 0.00068s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 349, Feedback: +--
# Computer tries permutation: 394, Feedback: ---
# Computer tries permutation: 439, Feedback: +++
# The computer guessed the secret number: 439
# Tested Secret: 439, Attempts: 15, Time: 0.02235s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 145, Feedback: ---
# Computer tries permutation: 154, Feedback: +--
# Computer tries permutation: 415, Feedback: +--
# Computer tries permutation: 451, Feedback: +++
# The computer guessed the secret number: 451
# Tested Secret: 451, Attempts: 11, Time: 0.00036s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 245, Feedback: ---
# Computer tries permutation: 254, Feedback: +--
# Computer tries permutation: 425, Feedback: +--
# Computer tries permutation: 452, Feedback: +++
# The computer guessed the secret number: 452
# Tested Secret: 452, Attempts: 11, Time: 0.00060s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 345, Feedback: ---
# Computer tries permutation: 354, Feedback: +--
# Computer tries permutation: 435, Feedback: +--
# Computer tries permutation: 453, Feedback: +++
# The computer guessed the secret number: 453
# Tested Secret: 453, Attempts: 11, Time: 0.01032s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +++
# The computer guessed the secret number: 456
# Tested Secret: 456, Attempts: 2, Time: 0.00014s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 457, Feedback: +++
# The computer guessed the secret number: 457
# Tested Secret: 457, Attempts: 8, Time: 0.00039s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 458, Feedback: +++
# The computer guessed the secret number: 458
# Tested Secret: 458, Attempts: 9, Time: 0.00034s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 459, Feedback: +++
# The computer guessed the secret number: 459
# Tested Secret: 459, Attempts: 10, Time: 0.00037s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 146, Feedback: ---
# Computer tries permutation: 164, Feedback: +--
# Computer tries permutation: 416, Feedback: +--
# Computer tries permutation: 461, Feedback: +++
# The computer guessed the secret number: 461
# Tested Secret: 461, Attempts: 12, Time: 0.00044s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 246, Feedback: ---
# Computer tries permutation: 264, Feedback: +--
# Computer tries permutation: 426, Feedback: +--
# Computer tries permutation: 462, Feedback: +++
# The computer guessed the secret number: 462
# Tested Secret: 462, Attempts: 12, Time: 0.00045s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 346, Feedback: ---
# Computer tries permutation: 364, Feedback: +--
# Computer tries permutation: 436, Feedback: +--
# Computer tries permutation: 463, Feedback: +++
# The computer guessed the secret number: 463
# Tested Secret: 463, Attempts: 12, Time: 0.00046s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +--
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 456, Feedback: +--
# Computer tries permutation: 465, Feedback: +++
# The computer guessed the secret number: 465
# Tested Secret: 465, Attempts: 7, Time: 0.00029s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 467, Feedback: +++
# The computer guessed the secret number: 467
# Tested Secret: 467, Attempts: 8, Time: 0.00033s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 468, Feedback: +++
# The computer guessed the secret number: 468
# Tested Secret: 468, Attempts: 9, Time: 0.10950s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 469, Feedback: +++
# The computer guessed the secret number: 469
# Tested Secret: 469, Attempts: 10, Time: 0.00040s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 147, Feedback: ---
# Computer tries permutation: 174, Feedback: +--
# Computer tries permutation: 417, Feedback: +--
# Computer tries permutation: 471, Feedback: +++
# The computer guessed the secret number: 471
# Tested Secret: 471, Attempts: 14, Time: 0.04071s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 247, Feedback: ---
# Computer tries permutation: 274, Feedback: +--
# Computer tries permutation: 427, Feedback: +--
# Computer tries permutation: 472, Feedback: +++
# The computer guessed the secret number: 472
# Tested Secret: 472, Attempts: 14, Time: 0.00932s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 347, Feedback: ---
# Computer tries permutation: 374, Feedback: +--
# Computer tries permutation: 437, Feedback: +--
# Computer tries permutation: 473, Feedback: +++
# The computer guessed the secret number: 473
# Tested Secret: 473, Attempts: 14, Time: 0.00054s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 457, Feedback: +--
# Computer tries permutation: 475, Feedback: +++
# The computer guessed the secret number: 475
# Tested Secret: 475, Attempts: 9, Time: 0.00343s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 467, Feedback: +--
# Computer tries permutation: 476, Feedback: +++
# The computer guessed the secret number: 476
# Tested Secret: 476, Attempts: 9, Time: 0.00031s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 478, Feedback: +++
# The computer guessed the secret number: 478
# Tested Secret: 478, Attempts: 9, Time: 0.00042s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +-
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 479, Feedback: +++
# The computer guessed the secret number: 479
# Tested Secret: 479, Attempts: 10, Time: 0.00071s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 148, Feedback: ---
# Computer tries permutation: 184, Feedback: +--
# Computer tries permutation: 418, Feedback: +--
# Computer tries permutation: 481, Feedback: +++
# The computer guessed the secret number: 481
# Tested Secret: 481, Attempts: 15, Time: 0.02621s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 248, Feedback: ---
# Computer tries permutation: 284, Feedback: +--
# Computer tries permutation: 428, Feedback: +--
# Computer tries permutation: 482, Feedback: +++
# The computer guessed the secret number: 482
# Tested Secret: 482, Attempts: 15, Time: 0.00286s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 348, Feedback: ---
# Computer tries permutation: 384, Feedback: +--
# Computer tries permutation: 438, Feedback: +--
# Computer tries permutation: 483, Feedback: +++
# The computer guessed the secret number: 483
# Tested Secret: 483, Attempts: 15, Time: 0.00054s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 458, Feedback: +--
# Computer tries permutation: 485, Feedback: +++
# The computer guessed the secret number: 485
# Tested Secret: 485, Attempts: 10, Time: 0.01298s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 468, Feedback: +--
# Computer tries permutation: 486, Feedback: +++
# The computer guessed the secret number: 486
# Tested Secret: 486, Attempts: 10, Time: 0.00040s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +-
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 478, Feedback: +--
# Computer tries permutation: 487, Feedback: +++
# The computer guessed the secret number: 487
# Tested Secret: 487, Attempts: 10, Time: 0.00041s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: ++
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 489, Feedback: +++
# The computer guessed the secret number: 489
# Tested Secret: 489, Attempts: 10, Time: 0.00090s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 149, Feedback: ---
# Computer tries permutation: 194, Feedback: +--
# Computer tries permutation: 419, Feedback: +--
# Computer tries permutation: 491, Feedback: +++
# The computer guessed the secret number: 491
# Tested Secret: 491, Attempts: 16, Time: 0.02140s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 249, Feedback: ---
# Computer tries permutation: 294, Feedback: +--
# Computer tries permutation: 429, Feedback: +--
# Computer tries permutation: 492, Feedback: +++
# The computer guessed the secret number: 492
# Tested Secret: 492, Attempts: 16, Time: 0.00060s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 349, Feedback: ---
# Computer tries permutation: 394, Feedback: +--
# Computer tries permutation: 439, Feedback: +--
# Computer tries permutation: 493, Feedback: +++
# The computer guessed the secret number: 493
# Tested Secret: 493, Attempts: 16, Time: 0.00058s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 459, Feedback: +--
# Computer tries permutation: 495, Feedback: +++
# The computer guessed the secret number: 495
# Tested Secret: 495, Attempts: 11, Time: 0.00041s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: ++
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 469, Feedback: +--
# Computer tries permutation: 496, Feedback: +++
# The computer guessed the secret number: 496
# Tested Secret: 496, Attempts: 11, Time: 0.00039s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 479, Feedback: +--
# Computer tries permutation: 497, Feedback: +++
# The computer guessed the secret number: 497
# Tested Secret: 497, Attempts: 11, Time: 0.00114s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 489, Feedback: +--
# Computer tries permutation: 498, Feedback: +++
# The computer guessed the secret number: 498
# Tested Secret: 498, Attempts: 11, Time: 0.00041s
# Computer's guess: 123, Feedback: --
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 125, Feedback: ---
# Computer tries permutation: 152, Feedback: +--
# Computer tries permutation: 215, Feedback: +--
# Computer tries permutation: 251, Feedback: ---
# Computer tries permutation: 512, Feedback: +++
# The computer guessed the secret number: 512
# Tested Secret: 512, Attempts: 12, Time: 0.01242s
# Computer's guess: 123, Feedback: +-
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 135, Feedback: ---
# Computer tries permutation: 153, Feedback: +--
# Computer tries permutation: 315, Feedback: +--
# Computer tries permutation: 351, Feedback: ---
# Computer tries permutation: 513, Feedback: +++
# The computer guessed the secret number: 513
# Tested Secret: 513, Attempts: 12, Time: 0.00050s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 145, Feedback: ---
# Computer tries permutation: 154, Feedback: +--
# Computer tries permutation: 415, Feedback: +--
# Computer tries permutation: 451, Feedback: ---
# Computer tries permutation: 514, Feedback: +++
# The computer guessed the secret number: 514
# Tested Secret: 514, Attempts: 12, Time: 0.00047s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 156, Feedback: +--
# Computer tries permutation: 165, Feedback: ---
# Computer tries permutation: 516, Feedback: +++
# The computer guessed the secret number: 516
# Tested Secret: 516, Attempts: 11, Time: 0.01609s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 157, Feedback: +--
# Computer tries permutation: 175, Feedback: ---
# Computer tries permutation: 517, Feedback: +++
# The computer guessed the secret number: 517
# Tested Secret: 517, Attempts: 13, Time: 0.00067s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 158, Feedback: +--
# Computer tries permutation: 185, Feedback: ---
# Computer tries permutation: 518, Feedback: +++
# The computer guessed the secret number: 518
# Tested Secret: 518, Attempts: 14, Time: 0.01186s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 159, Feedback: +--
# Computer tries permutation: 195, Feedback: ---
# Computer tries permutation: 519, Feedback: +++
# The computer guessed the secret number: 519
# Tested Secret: 519, Attempts: 15, Time: 0.00172s
# Computer's guess: 123, Feedback: +-
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 125, Feedback: +--
# Computer tries permutation: 152, Feedback: ---
# Computer tries permutation: 215, Feedback: ---
# Computer tries permutation: 251, Feedback: +--
# Computer tries permutation: 512, Feedback: +--
# Computer tries permutation: 521, Feedback: +++
# The computer guessed the secret number: 521
# Tested Secret: 521, Attempts: 13, Time: 0.00085s
# Computer's guess: 123, Feedback: ++
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 235, Feedback: ---
# Computer tries permutation: 253, Feedback: +--
# Computer tries permutation: 325, Feedback: +--
# Computer tries permutation: 352, Feedback: ---
# Computer tries permutation: 523, Feedback: +++
# The computer guessed the secret number: 523
# Tested Secret: 523, Attempts: 12, Time: 0.00049s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 245, Feedback: ---
# Computer tries permutation: 254, Feedback: +--
# Computer tries permutation: 425, Feedback: +--
# Computer tries permutation: 452, Feedback: ---
# Computer tries permutation: 524, Feedback: +++
# The computer guessed the secret number: 524
# Tested Secret: 524, Attempts: 12, Time: 0.01756s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 256, Feedback: +--
# Computer tries permutation: 265, Feedback: ---
# Computer tries permutation: 526, Feedback: +++
# The computer guessed the secret number: 526
# Tested Secret: 526, Attempts: 11, Time: 0.00037s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 257, Feedback: +--
# Computer tries permutation: 275, Feedback: ---
# Computer tries permutation: 527, Feedback: +++
# The computer guessed the secret number: 527
# Tested Secret: 527, Attempts: 13, Time: 0.00933s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 258, Feedback: +--
# Computer tries permutation: 285, Feedback: ---
# Computer tries permutation: 528, Feedback: +++
# The computer guessed the secret number: 528
# Tested Secret: 528, Attempts: 14, Time: 0.00075s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 259, Feedback: +--
# Computer tries permutation: 295, Feedback: ---
# Computer tries permutation: 529, Feedback: +++
# The computer guessed the secret number: 529
# Tested Secret: 529, Attempts: 15, Time: 0.01546s
# Computer's guess: 123, Feedback: --
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 135, Feedback: +--
# Computer tries permutation: 153, Feedback: ---
# Computer tries permutation: 315, Feedback: ---
# Computer tries permutation: 351, Feedback: +--
# Computer tries permutation: 513, Feedback: +--
# Computer tries permutation: 531, Feedback: +++
# The computer guessed the secret number: 531
# Tested Secret: 531, Attempts: 13, Time: 0.00178s
# Computer's guess: 123, Feedback: --
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 235, Feedback: +--
# Computer tries permutation: 253, Feedback: ---
# Computer tries permutation: 325, Feedback: ---
# Computer tries permutation: 352, Feedback: +--
# Computer tries permutation: 523, Feedback: +--
# Computer tries permutation: 532, Feedback: +++
# The computer guessed the secret number: 532
# Tested Secret: 532, Attempts: 13, Time: 0.00038s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 345, Feedback: ---
# Computer tries permutation: 354, Feedback: +--
# Computer tries permutation: 435, Feedback: +--
# Computer tries permutation: 453, Feedback: ---
# Computer tries permutation: 534, Feedback: +++
# The computer guessed the secret number: 534
# Tested Secret: 534, Attempts: 12, Time: 0.00034s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 356, Feedback: +--
# Computer tries permutation: 365, Feedback: ---
# Computer tries permutation: 536, Feedback: +++
# The computer guessed the secret number: 536
# Tested Secret: 536, Attempts: 11, Time: 0.00028s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 357, Feedback: +--
# Computer tries permutation: 375, Feedback: ---
# Computer tries permutation: 537, Feedback: +++
# The computer guessed the secret number: 537
# Tested Secret: 537, Attempts: 13, Time: 0.00033s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 358, Feedback: +--
# Computer tries permutation: 385, Feedback: ---
# Computer tries permutation: 538, Feedback: +++
# The computer guessed the secret number: 538
# Tested Secret: 538, Attempts: 14, Time: 0.00436s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 359, Feedback: +--
# Computer tries permutation: 395, Feedback: ---
# Computer tries permutation: 539, Feedback: +++
# The computer guessed the secret number: 539
# Tested Secret: 539, Attempts: 15, Time: 0.03187s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 145, Feedback: +--
# Computer tries permutation: 154, Feedback: ---
# Computer tries permutation: 415, Feedback: ---
# Computer tries permutation: 451, Feedback: +--
# Computer tries permutation: 514, Feedback: +--
# Computer tries permutation: 541, Feedback: +++
# The computer guessed the secret number: 541
# Tested Secret: 541, Attempts: 13, Time: 0.00051s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 245, Feedback: +--
# Computer tries permutation: 254, Feedback: ---
# Computer tries permutation: 425, Feedback: ---
# Computer tries permutation: 452, Feedback: +--
# Computer tries permutation: 524, Feedback: +--
# Computer tries permutation: 542, Feedback: +++
# The computer guessed the secret number: 542
# Tested Secret: 542, Attempts: 13, Time: 0.00052s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer tries permutation: 345, Feedback: +--
# Computer tries permutation: 354, Feedback: ---
# Computer tries permutation: 435, Feedback: ---
# Computer tries permutation: 453, Feedback: +--
# Computer tries permutation: 534, Feedback: +--
# Computer tries permutation: 543, Feedback: +++
# The computer guessed the secret number: 543
# Tested Secret: 543, Attempts: 13, Time: 0.00058s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +--
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 456, Feedback: +--
# Computer tries permutation: 465, Feedback: ---
# Computer tries permutation: 546, Feedback: +++
# The computer guessed the secret number: 546
# Tested Secret: 546, Attempts: 8, Time: 0.01457s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 457, Feedback: +--
# Computer tries permutation: 475, Feedback: ---
# Computer tries permutation: 547, Feedback: +++
# The computer guessed the secret number: 547
# Tested Secret: 547, Attempts: 10, Time: 0.00993s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 458, Feedback: +--
# Computer tries permutation: 485, Feedback: ---
# Computer tries permutation: 548, Feedback: +++
# The computer guessed the secret number: 548
# Tested Secret: 548, Attempts: 11, Time: 0.00043s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 459, Feedback: +--
# Computer tries permutation: 495, Feedback: ---
# Computer tries permutation: 549, Feedback: +++
# The computer guessed the secret number: 549
# Tested Secret: 549, Attempts: 12, Time: 0.00066s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 156, Feedback: ---
# Computer tries permutation: 165, Feedback: +--
# Computer tries permutation: 516, Feedback: +--
# Computer tries permutation: 561, Feedback: +++
# The computer guessed the secret number: 561
# Tested Secret: 561, Attempts: 12, Time: 0.00048s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 256, Feedback: ---
# Computer tries permutation: 265, Feedback: +--
# Computer tries permutation: 526, Feedback: +--
# Computer tries permutation: 562, Feedback: +++
# The computer guessed the secret number: 562
# Tested Secret: 562, Attempts: 12, Time: 0.02050s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 356, Feedback: ---
# Computer tries permutation: 365, Feedback: +--
# Computer tries permutation: 536, Feedback: +--
# Computer tries permutation: 563, Feedback: +++
# The computer guessed the secret number: 563
# Tested Secret: 563, Attempts: 12, Time: 0.00052s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: ---
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer tries permutation: 456, Feedback: ---
# Computer tries permutation: 465, Feedback: +--
# Computer tries permutation: 546, Feedback: +--
# Computer tries permutation: 564, Feedback: +++
# The computer guessed the secret number: 564
# Tested Secret: 564, Attempts: 9, Time: 0.00038s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 567, Feedback: +++
# The computer guessed the secret number: 567
# Tested Secret: 567, Attempts: 8, Time: 0.00035s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer tries permutation: 568, Feedback: +++
# The computer guessed the secret number: 568
# Tested Secret: 568, Attempts: 9, Time: 0.00038s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: +
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 569, Feedback: +++
# The computer guessed the secret number: 569
# Tested Secret: 569, Attempts: 10, Time: 0.00040s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 157, Feedback: ---
# Computer tries permutation: 175, Feedback: +--
# Computer tries permutation: 517, Feedback: +--
# Computer tries permutation: 571, Feedback: +++
# The computer guessed the secret number: 571
# Tested Secret: 571, Attempts: 14, Time: 0.00053s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 257, Feedback: ---
# Computer tries permutation: 275, Feedback: +--
# Computer tries permutation: 527, Feedback: +--
# Computer tries permutation: 572, Feedback: +++
# The computer guessed the secret number: 572
# Tested Secret: 572, Attempts: 14, Time: 0.00049s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 357, Feedback: ---
# Computer tries permutation: 375, Feedback: +--
# Computer tries permutation: 537, Feedback: +--
# Computer tries permutation: 573, Feedback: +++
# The computer guessed the secret number: 573
# Tested Secret: 573, Attempts: 14, Time: 0.00053s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 457, Feedback: ---
# Computer tries permutation: 475, Feedback: +--
# Computer tries permutation: 547, Feedback: +--
# Computer tries permutation: 574, Feedback: +++
# The computer guessed the secret number: 574
# Tested Secret: 574, Attempts: 11, Time: 0.01745s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +-
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback: +
# Computer tries permutation: 567, Feedback: +--
# Computer tries permutation: 576, Feedback: +++
# The computer guessed the secret number: 576
# Tested Secret: 576, Attempts: 9, Time: 0.00041s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: --
# ...
# Computer tries permutation: 659, Feedback: +--
# Computer tries permutation: 695, Feedback: ---
# Computer tries permutation: 956, Feedback: +++
# The computer guessed the secret number: 956
# Tested Secret: 956, Attempts: 14, Time: 0.00037s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 579, Feedback: ---
# Computer tries permutation: 597, Feedback: +--
# Computer tries permutation: 759, Feedback: +--
# Computer tries permutation: 795, Feedback: ---
# Computer tries permutation: 957, Feedback: +++
# The computer guessed the secret number: 957
# Tested Secret: 957, Attempts: 14, Time: 0.00037s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 589, Feedback: ---
# Computer tries permutation: 598, Feedback: +--
# Computer tries permutation: 859, Feedback: +--
# Computer tries permutation: 895, Feedback: ---
# Computer tries permutation: 958, Feedback: +++
# The computer guessed the secret number: 958
# Tested Secret: 958, Attempts: 14, Time: 0.00049s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 169, Feedback: +--
# Computer tries permutation: 196, Feedback: ---
# Computer tries permutation: 619, Feedback: ---
# Computer tries permutation: 691, Feedback: +--
# Computer tries permutation: 916, Feedback: +--
# Computer tries permutation: 961, Feedback: +++
# The computer guessed the secret number: 961
# Tested Secret: 961, Attempts: 18, Time: 0.00063s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 269, Feedback: +--
# Computer tries permutation: 296, Feedback: ---
# Computer tries permutation: 629, Feedback: ---
# Computer tries permutation: 692, Feedback: +--
# Computer tries permutation: 926, Feedback: +--
# Computer tries permutation: 962, Feedback: +++
# The computer guessed the secret number: 962
# Tested Secret: 962, Attempts: 18, Time: 0.00085s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 369, Feedback: +--
# Computer tries permutation: 396, Feedback: ---
# Computer tries permutation: 639, Feedback: ---
# Computer tries permutation: 693, Feedback: +--
# Computer tries permutation: 936, Feedback: +--
# Computer tries permutation: 963, Feedback: +++
# The computer guessed the secret number: 963
# Tested Secret: 963, Attempts: 18, Time: 0.00071s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 469, Feedback: +--
# Computer tries permutation: 496, Feedback: ---
# Computer tries permutation: 649, Feedback: ---
# Computer tries permutation: 694, Feedback: +--
# Computer tries permutation: 946, Feedback: +--
# Computer tries permutation: 964, Feedback: +++
# The computer guessed the secret number: 964
# Tested Secret: 964, Attempts: 15, Time: 0.06136s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: --
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: -
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 569, Feedback: +--
# Computer tries permutation: 596, Feedback: ---
# Computer tries permutation: 659, Feedback: ---
# Computer tries permutation: 695, Feedback: +--
# Computer tries permutation: 956, Feedback: +--
# Computer tries permutation: 965, Feedback: +++
# The computer guessed the secret number: 965
# Tested Secret: 965, Attempts: 15, Time: 0.00925s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 679, Feedback: ---
# Computer tries permutation: 697, Feedback: +--
# Computer tries permutation: 769, Feedback: +--
# Computer tries permutation: 796, Feedback: ---
# Computer tries permutation: 967, Feedback: +++
# The computer guessed the secret number: 967
# Tested Secret: 967, Attempts: 14, Time: 0.00054s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 689, Feedback: ---
# Computer tries permutation: 698, Feedback: +--
# Computer tries permutation: 869, Feedback: +--
# Computer tries permutation: 896, Feedback: ---
# Computer tries permutation: 968, Feedback: +++
# The computer guessed the secret number: 968
# Tested Secret: 968, Attempts: 14, Time: 0.00706s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 179, Feedback: +--
# Computer tries permutation: 197, Feedback: ---
# Computer tries permutation: 719, Feedback: ---
# Computer tries permutation: 791, Feedback: +--
# Computer tries permutation: 917, Feedback: +--
# Computer tries permutation: 971, Feedback: +++
# The computer guessed the secret number: 971
# Tested Secret: 971, Attempts: 15, Time: 0.00135s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 279, Feedback: +--
# Computer tries permutation: 297, Feedback: ---
# Computer tries permutation: 729, Feedback: ---
# Computer tries permutation: 792, Feedback: +--
# Computer tries permutation: 927, Feedback: +--
# Computer tries permutation: 972, Feedback: +++
# The computer guessed the secret number: 972
# Tested Secret: 972, Attempts: 15, Time: 0.00056s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 379, Feedback: +--
# Computer tries permutation: 397, Feedback: ---
# Computer tries permutation: 739, Feedback: ---
# Computer tries permutation: 793, Feedback: +--
# Computer tries permutation: 937, Feedback: +--
# Computer tries permutation: 973, Feedback: +++
# The computer guessed the secret number: 973
# Tested Secret: 973, Attempts: 15, Time: 0.00435s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 479, Feedback: +--
# Computer tries permutation: 497, Feedback: ---
# Computer tries permutation: 749, Feedback: ---
# Computer tries permutation: 794, Feedback: +--
# Computer tries permutation: 947, Feedback: +--
# Computer tries permutation: 974, Feedback: +++
# The computer guessed the secret number: 974
# Tested Secret: 974, Attempts: 15, Time: 0.02237s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 579, Feedback: +--
# Computer tries permutation: 597, Feedback: ---
# Computer tries permutation: 759, Feedback: ---
# Computer tries permutation: 795, Feedback: +--
# Computer tries permutation: 957, Feedback: +--
# Computer tries permutation: 975, Feedback: +++
# The computer guessed the secret number: 975
# Tested Secret: 975, Attempts: 15, Time: 0.00603s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: --
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback:
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 679, Feedback: +--
# Computer tries permutation: 697, Feedback: ---
# Computer tries permutation: 769, Feedback: ---
# Computer tries permutation: 796, Feedback: +--
# Computer tries permutation: 967, Feedback: +--
# Computer tries permutation: 976, Feedback: +++
# The computer guessed the secret number: 976
# Tested Secret: 976, Attempts: 15, Time: 0.00682s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback:
# Computer's guess: 789, Feedback: ---
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 789, Feedback: ---
# Computer tries permutation: 798, Feedback: +--
# Computer tries permutation: 879, Feedback: +--
# Computer tries permutation: 897, Feedback: ---
# Computer tries permutation: 978, Feedback: +++
# The computer guessed the secret number: 978
# Tested Secret: 978, Attempts: 11, Time: 0.00605s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback: +
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback:
# Computer's guess: 789, Feedback: +-
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 189, Feedback: +--
# Computer tries permutation: 198, Feedback: ---
# Computer tries permutation: 819, Feedback: ---
# Computer tries permutation: 891, Feedback: +--
# Computer tries permutation: 918, Feedback: +--
# Computer tries permutation: 981, Feedback: +++
# The computer guessed the secret number: 981
# Tested Secret: 981, Attempts: 15, Time: 0.00865s
# Computer's guess: 123, Feedback: -
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback: +
# Computer's guess: 333, Feedback:
# Computer's guess: 456, Feedback:
# Computer's guess: 789, Feedback: +-
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 289, Feedback: +--
# Computer tries permutation: 298, Feedback: ---
# Computer tries permutation: 829, Feedback: ---
# Computer tries permutation: 892, Feedback: +--
# Computer tries permutation: 928, Feedback: +--
# Computer tries permutation: 982, Feedback: +++
# The computer guessed the secret number: 982
# Tested Secret: 982, Attempts: 15, Time: 0.00479s
# Computer's guess: 123, Feedback: +
# Computer's guess: 111, Feedback:
# Computer's guess: 222, Feedback:
# Computer's guess: 333, Feedback: +
# Computer's guess: 456, Feedback:
# Computer's guess: 789, Feedback: +-
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 389, Feedback: +--
# Computer tries permutation: 398, Feedback: ---
# Computer tries permutation: 839, Feedback: ---
# Computer tries permutation: 893, Feedback: +--
# Computer tries permutation: 938, Feedback: +--
# Computer tries permutation: 983, Feedback: +++
# The computer guessed the secret number: 983
# Tested Secret: 983, Attempts: 15, Time: 0.00054s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback: +
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +-
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 489, Feedback: +--
# Computer tries permutation: 498, Feedback: ---
# Computer tries permutation: 849, Feedback: ---
# Computer tries permutation: 894, Feedback: +--
# Computer tries permutation: 948, Feedback: +--
# Computer tries permutation: 984, Feedback: +++
# The computer guessed the secret number: 984
# Tested Secret: 984, Attempts: 15, Time: 0.00980s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: -
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback: +
# Computer's guess: 666, Feedback:
# Computer's guess: 789, Feedback: +-
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 589, Feedback: +--
# Computer tries permutation: 598, Feedback: ---
# Computer tries permutation: 859, Feedback: ---
# Computer tries permutation: 895, Feedback: +--
# Computer tries permutation: 958, Feedback: +--
# Computer tries permutation: 985, Feedback: +++
# The computer guessed the secret number: 985
# Tested Secret: 985, Attempts: 15, Time: 0.00057s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback: +
# Computer's guess: 444, Feedback:
# Computer's guess: 555, Feedback:
# Computer's guess: 666, Feedback: +
# Computer's guess: 789, Feedback: +-
# Computer's guess: 777, Feedback:
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 689, Feedback: +--
# Computer tries permutation: 698, Feedback: ---
# Computer tries permutation: 869, Feedback: ---
# Computer tries permutation: 896, Feedback: +--
# Computer tries permutation: 968, Feedback: +--
# Computer tries permutation: 986, Feedback: +++
# The computer guessed the secret number: 986
# Tested Secret: 986, Attempts: 15, Time: 0.00056s
# Computer's guess: 123, Feedback:
# Computer's guess: 456, Feedback:
# Computer's guess: 789, Feedback: +--
# Computer's guess: 777, Feedback: +
# Computer's guess: 888, Feedback: +
# Computer's guess: 999, Feedback: +
# Computer tries permutation: 789, Feedback: +--
# Computer tries permutation: 798, Feedback: ---
# Computer tries permutation: 879, Feedback: ---
# Computer tries permutation: 897, Feedback: +--
# Computer tries permutation: 978, Feedback: +--
# Computer tries permutation: 987, Feedback: +++
# The computer guessed the secret number: 987
# Tested Secret: 987, Attempts: 12, Time: 0.00045s
#
# Worst Case Found!
# Secret Number: 952
# Max Attempts: 18
# Max Time Taken: 0.04613s
